# %%
import pandas as pd
import os
import warnings
import numpy as np
warnings.filterwarnings(action='ignore')

from itertools import chain
from collections import Counter

problem = pd.read_csv('/content/problemList.csv',encoding="ISO-8859-1")

# %%
problem.head()
# Out:
#    Unnamed: 0  problemId          title  acceptedUserCount  level  \
# 0           0       1000            A+B             272273      1
# 1           0       1001            A-B             232650      1
# 2           0       1002           ÅÍ·¿              35292      8
# 3           0       1003  ÇÇº¸³ªÄ¡ ÇÔ¼ö              49732      8
# 4           0       1004      ¾î¸° ¿ÕÀÚ              14695      8
#
#                                         key         bojTagId
# 0  ['implementation', 'arithmetic', 'math']  [102, 121, 124]
# 1  ['implementation', 'arithmetic', 'math']  [102, 121, 124]
# 2         ['case_work', 'geometry', 'math']  [137, 100, 124]
# 3                                    ['dp']             [25]
# 4                      ['geometry', 'math']       [100, 124]

# %%
problem.columns
# Out:
# Index(['Unnamed: 0', 'problemId', 'title', 'acceptedUserCount', 'level', 'key',
#        'bojTagId'],
#       dtype='object')

# %%
tags_problem = problem[problem['bojTagId'] != '[]']
tags_problem['tags_count'] = tags_problem['bojTagId'].apply(lambda x: len(x.split('}]},')))
tags_problem['tags_count'].describe()
# Out:
# count    21028.0
# mean         1.0
# std          0.0
# min          1.0
# 25%          1.0
# 50%          1.0
# 75%          1.0
# max          1.0
# Name: tags_count, dtype: float64

# %%
problem['level'].describe()
# Out:
# count    29166.000000
# mean        10.184118
# std          8.122821
# min          0.000000
# 25%          0.000000
# 50%         10.000000
# 75%         17.000000
# max         30.000000
# Name: level, dtype: float64

# %%
problem['key'].unique()
# Out:
# array(["['implementation', 'arithmetic', 'math']",
#        "['case_work', 'geometry', 'math']", "['dp']", ...,
#        "['math', 'prefix_sum', 'sorting', 'ternary_search']",
#        "['data_structures', 'greedy', 'priority_queue', 'tree_set', 'two_pointer']",
#        "['case_work', 'implementation', 'prefix_sum', 'simulation']"],
#       dtype=object)

# %%
problem_level = problem.groupby('level')[['problemId']].agg('count').rename(columns={'problemId':'problem'})
problem_level
# Out:
#        problem
# level
# 0         7545
# 1          141
# 2          241
# 3          666
# 4          840
# 5          763
# 6          734
# 7          839
# 8          941
# 9          919
# 10         980
# 11        1027
# 12        1323
# 13        1243
# 14        1085
# 15        1014
# 16        1144
# 17        1067
# 18        1119
# 19        1083
# 20         859
# 21         871
# 22         834
# 23         590
# 24         414
# 25         347
# 26         257
# 27         138
# 28          87
# 29          30
# 30          25

# %%
problem['problemId'].explode()
problem['problemId'].dropna(axis=0)
# Out:
# 0         1000
# 1         1001
# 2         1002
# 3         1003
# 4         1004
#          ...
# 29161    31060
# 29162    31061
# 29163    31062
# 29164    31063
# 29165    31064
# Name: problemId, Length: 29166, dtype: int64
